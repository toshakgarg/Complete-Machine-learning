# %% [markdown]
# # Initial Setup

# %% [markdown]
# ## Import all required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read the DataFrame

# %%
# prompt: generate the code to change the current working directory to main directory

import os

# Check the current working directory
print(os.getcwd())

# Change the current working directory
os.chdir('/content/drive/MyDrive/Complete Machine Learning/Machine learning/Supervised ML Models') # Write the current working directory as parameter

# Check the current working directory
print(os.getcwd())

# List contents of the main directory (root directory)
# !ls
# Out:
# /content
# /content/drive/MyDrive/Complete Machine Learning/Machine learning/Supervised ML Models
# 'Practical implementation of Decision tree.ipynb'
#  Projects
# 'Simple Linear Regression.ipynb'
#  winequality-red.csv

# %%
dataframe = pd.read_csv('winequality-red.csv')
dataframe.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
dataframe.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
set(dataframe['quality'])
# Out:
# {3, 4, 5, 6, 7, 8}

# %% [markdown]
# Therefore this problem is of multiclass-classification problems

# %% [markdown]
# # Spliting the Data into X(Independent Features) and Y(target columns)

# %%
X = dataframe.drop('quality', axis=1)
Y = dataframe['quality']

# %%
X.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %% [markdown]
# # Train Test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y)

# %% [markdown]
# # Model Training

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([5, 5, 5, 6, 5, 5, 5, 7, 5, 5, 7, 7, 5, 7, 5, 6, 5, 5, 6, 4, 5, 6,
#        6, 6, 4, 6, 6, 8, 7, 4, 5, 5, 4, 6, 6, 6, 5, 5, 6, 5, 5, 7, 5, 6,
#        5, 7, 7, 4, 5, 5, 6, 5, 6, 4, 6, 7, 5, 5, 5, 6, 5, 8, 5, 5, 5, 6,
#        6, 7, 5, 6, 5, 6, 6, 5, 6, 7, 6, 5, 6, 5, 6, 5, 6, 6, 6, 5, 5, 5,
#        4, 5, 6, 6, 7, 5, 6, 6, 5, 5, 6, 6, 5, 6, 6, 5, 6, 6, 6, 5, 5, 5,
#        6, 4, 4, 7, 6, 6, 5, 7, 6, 5, 5, 4, 5, 7, 7, 5, 7, 7, 3, 5, 7, 5,
#        5, 7, 7, 5, 5, 6, 6, 5, 5, 6, 8, 7, 5, 5, 5, 5, 5, 6, 6, 6, 5, 5,
#        6, 7, 7, 6, 6, 5, 5, 6, 7, 6, 6, 5, 5, 6, 5, 5, 5, 5, 5, 5, 7, 5,
#        6, 6, 5, 5, 5, 6, 6, 6, 5, 6, 5, 6, 6, 6, 8, 5, 5, 7, 6, 6, 7, 7,
#        6, 6, 5, 6, 5, 5, 4, 6, 5, 6, 5, 7, 5, 5, 7, 5, 5, 5, 5, 5, 5, 7,
#        5, 5, 5, 5, 6, 6, 6, 5, 6, 6, 5, 5, 5, 5, 6, 6, 5, 5, 7, 6, 6, 6,
#        7, 6, 5, 5, 5, 7, 6, 6, 6, 6, 5, 6, 6, 6, 6, 6, 7, 7, 7, 5, 7, 5,
#        6, 6, 6, 6, 7, 6, 6, 6, 5, 5, 6, 6, 7, 5, 4, 4, 5, 8, 6, 7, 5, 4,
#        5, 6, 6, 6, 6, 5, 4, 6, 5, 6, 6, 6, 7, 7, 4, 5, 5, 5, 7, 7, 6, 6,
#        5, 5, 5, 5, 6, 6, 6, 6, 6, 5, 6, 6, 7, 5, 5, 5, 5, 6, 6, 6, 7, 6,
#        7, 5, 6, 5, 6, 7, 6, 6, 6, 6, 6, 5, 6, 5, 7, 5, 7, 5, 5, 6, 7, 6,
#        4, 6, 8, 6, 7, 8, 5, 5, 6, 6, 6, 4, 5, 6, 6, 5, 6, 6, 7, 6, 6, 6,
#        4, 6, 6, 5, 5, 5, 5, 5, 5, 6, 5, 6, 6, 6, 6, 5, 6, 5, 5, 5, 6, 5,
#        6, 5, 5, 6])

# %% [markdown]
# # Ploting the Tree

# %%
from sklearn import tree
plt.figure(figsize=(25,20))
tree.plot_tree(model, filled = True)
# Out:
# [Text(0.523080585808154, 0.9761904761904762, 'x[10] <= 10.25\ngini = 0.646\nsamples = 1199\nvalue = [8, 41, 512, 471, 153, 14]'),
#  Text(0.33822449943087746, 0.9285714285714286, 'x[6] <= 95.5\ngini = 0.527\nsamples = 631\nvalue = [6, 22, 386, 196, 20, 1]'),
#  Text(0.4306525426195157, 0.9523809523809523, 'True  '),
#  Text(0.197972177669702, 0.8809523809523809, 'x[9] <= 0.555\ngini = 0.561\nsamples = 544\nvalue = [6, 21, 303, 193, 20, 1]'),
#  Text(0.060896109271523176, 0.8333333333333334, 'x[4] <= 0.082\ngini = 0.461\nsamples = 179\nvalue = [3.0, 15.0, 126.0, 34.0, 1.0, 0.0]'),
#  Text(0.03156043046357616, 0.7857142857142857, 'x[1] <= 0.46\ngini = 0.546\nsamples = 101\nvalue = [2.0, 8.0, 61.0, 29.0, 1.0, 0.0]'),
#  Text(0.013245033112582781, 0.7380952380952381, 'x[9] <= 0.505\ngini = 0.515\nsamples = 20\nvalue = [0, 1, 7, 12, 0, 0]'),
#  Text(0.006622516556291391, 0.6904761904761905, 'x[2] <= 0.155\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 6, 2, 0, 0]'),
#  Text(0.0033112582781456954, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.009933774834437087, 0.6428571428571429, 'x[8] <= 3.315\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.006622516556291391, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.013245033112582781, 0.5952380952380952, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.019867549668874173, 0.6904761904761905, 'x[7] <= 0.996\ngini = 0.292\nsamples = 12\nvalue = [0, 1, 1, 10, 0, 0]'),
#  Text(0.016556291390728478, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.023178807947019868, 0.6428571428571429, 'x[4] <= 0.061\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10, 0, 0]'),
#  Text(0.019867549668874173, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.026490066225165563, 0.5952380952380952, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.049875827814569534, 0.7380952380952381, 'x[6] <= 88.5\ngini = 0.503\nsamples = 81\nvalue = [2, 7, 54, 17, 1, 0]'),
#  Text(0.04656456953642384, 0.6904761904761905, 'x[6] <= 10.5\ngini = 0.48\nsamples = 78\nvalue = [2, 7, 54, 14, 1, 0]'),
#  Text(0.03642384105960265, 0.6428571428571429, 'x[7] <= 0.996\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 0, 3, 0, 0]'),
#  Text(0.033112582781456956, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.039735099337748346, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.05670529801324503, 0.6428571428571429, 'x[1] <= 0.857\ngini = 0.438\nsamples = 74\nvalue = [2, 6, 54, 11, 1, 0]'),
#  Text(0.046357615894039736, 0.5952380952380952, 'x[7] <= 0.998\ngini = 0.384\nsamples = 69\nvalue = [0, 5, 53, 10, 1, 0]'),
#  Text(0.03559602649006623, 0.5476190476190477, 'x[10] <= 9.075\ngini = 0.326\nsamples = 63\nvalue = [0, 3, 51, 8, 1, 0]'),
#  Text(0.027317880794701987, 0.5, 'x[7] <= 0.997\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0, 0, 0]'),
#  Text(0.024006622516556293, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.030629139072847682, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.043874172185430466, 0.5, 'x[7] <= 0.996\ngini = 0.287\nsamples = 60\nvalue = [0, 1, 50, 8, 1, 0]'),
#  Text(0.037251655629139076, 0.4523809523809524, 'x[3] <= 1.25\ngini = 0.071\nsamples = 27\nvalue = [0, 0, 26, 0, 1, 0]'),
#  Text(0.03394039735099338, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.04056291390728477, 0.40476190476190477, 'gini = 0.0\nsamples = 26\nvalue = [0, 0, 26, 0, 0, 0]'),
#  Text(0.050496688741721855, 0.4523809523809524, 'x[7] <= 0.997\ngini = 0.411\nsamples = 33\nvalue = [0, 1, 24, 8, 0, 0]'),
#  Text(0.04718543046357616, 0.40476190476190477, 'x[7] <= 0.997\ngini = 0.549\nsamples = 18\nvalue = [0, 1, 9, 8, 0, 0]'),
#  Text(0.043874172185430466, 0.35714285714285715, 'x[10] <= 9.65\ngini = 0.5\nsamples = 14\nvalue = [0, 1, 9, 4, 0, 0]'),
#  Text(0.037251655629139076, 0.30952380952380953, 'x[6] <= 37.5\ngini = 0.298\nsamples = 11\nvalue = [0, 0, 9, 2, 0, 0]'),
#  Text(0.03394039735099338, 0.2619047619047619, 'x[8] <= 3.245\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.030629139072847682, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.037251655629139076, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.04056291390728477, 0.2619047619047619, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.050496688741721855, 0.30952380952380953, 'x[1] <= 0.8\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]'),
#  Text(0.04718543046357616, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.05380794701986755, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.050496688741721855, 0.35714285714285715, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.05380794701986755, 0.40476190476190477, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0, 0, 0]'),
#  Text(0.057119205298013245, 0.5476190476190477, 'x[1] <= 0.67\ngini = 0.667\nsamples = 6\nvalue = [0, 2, 2, 2, 0, 0]'),
#  Text(0.05380794701986755, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.060430463576158944, 0.5, 'x[8] <= 3.43\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2, 0, 0, 0]'),
#  Text(0.057119205298013245, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.06374172185430464, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.06705298013245033, 0.5952380952380952, 'x[0] <= 7.75\ngini = 0.72\nsamples = 5\nvalue = [2, 1, 1, 1, 0, 0]'),
#  Text(0.06374172185430464, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]'),
#  Text(0.07036423841059603, 0.5476190476190477, 'x[8] <= 3.31\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 1, 0, 0]'),
#  Text(0.06705298013245033, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.07367549668874172, 0.5, 'x[7] <= 0.998\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.07036423841059603, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.07698675496688742, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.05318708609271523, 0.6904761904761905, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.0902317880794702, 0.7857142857142857, 'x[4] <= 0.226\ngini = 0.293\nsamples = 78\nvalue = [1, 7, 65, 5, 0, 0]'),
#  Text(0.0869205298013245, 0.7380952380952381, 'x[7] <= 0.994\ngini = 0.275\nsamples = 77\nvalue = [0.0, 7.0, 65.0, 5.0, 0.0, 0.0]'),
#  Text(0.0836092715231788, 0.6904761904761905, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.0902317880794702, 0.6904761904761905, 'x[10] <= 9.95\ngini = 0.258\nsamples = 76\nvalue = [0, 6, 65, 5, 0, 0]'),
#  Text(0.0802980132450331, 0.6428571428571429, 'x[10] <= 9.05\ngini = 0.177\nsamples = 62\nvalue = [0, 5, 56, 1, 0, 0]'),
#  Text(0.07698675496688742, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.0836092715231788, 0.5952380952380952, 'x[6] <= 12.5\ngini = 0.153\nsamples = 61\nvalue = [0, 4, 56, 1, 0, 0]'),
#  Text(0.0802980132450331, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.0869205298013245, 0.5476190476190477, 'x[7] <= 0.997\ngini = 0.126\nsamples = 60\nvalue = [0, 3, 56, 1, 0, 0]'),
#  Text(0.0836092715231788, 0.5, 'gini = 0.0\nsamples = 28\nvalue = [0, 0, 28, 0, 0, 0]'),
#  Text(0.0902317880794702, 0.5, 'x[7] <= 0.998\ngini = 0.225\nsamples = 32\nvalue = [0, 3, 28, 1, 0, 0]'),
#  Text(0.0836092715231788, 0.4523809523809524, 'x[8] <= 3.38\ngini = 0.49\nsamples = 7\nvalue = [0, 3, 4, 0, 0, 0]'),
#  Text(0.0802980132450331, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.0869205298013245, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.09685430463576158, 0.4523809523809524, 'x[3] <= 2.95\ngini = 0.077\nsamples = 25\nvalue = [0, 0, 24, 1, 0, 0]'),
#  Text(0.0935430463576159, 0.40476190476190477, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0, 0, 0]'),
#  Text(0.10016556291390728, 0.40476190476190477, 'x[3] <= 3.1\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.09685430463576158, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.10347682119205298, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.10016556291390728, 0.6428571428571429, 'x[2] <= 0.165\ngini = 0.5\nsamples = 14\nvalue = [0, 1, 9, 4, 0, 0]'),
#  Text(0.09685430463576158, 0.5952380952380952, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.10347682119205298, 0.5952380952380952, 'x[5] <= 13.0\ngini = 0.5\nsamples = 6\nvalue = [0, 1, 1, 4, 0, 0]'),
#  Text(0.10016556291390728, 0.5476190476190477, 'x[5] <= 5.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.09685430463576158, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.10347682119205298, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.10678807947019868, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.0935430463576159, 0.7380952380952381, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.3350482460678808, 0.8333333333333334, 'x[0] <= 9.95\ngini = 0.572\nsamples = 365\nvalue = [3.0, 6.0, 177.0, 159.0, 19.0, 1.0]'),
#  Text(0.22431834644039736, 0.7857142857142857, 'x[1] <= 0.375\ngini = 0.541\nsamples = 291\nvalue = [0, 4, 161, 113, 12, 1]'),
#  Text(0.125, 0.7380952380952381, 'x[7] <= 0.996\ngini = 0.522\nsamples = 30\nvalue = [0, 0, 8, 19, 2, 1]'),
#  Text(0.11672185430463576, 0.6904761904761905, 'x[5] <= 16.5\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 3, 0, 1, 1]'),
#  Text(0.11341059602649006, 0.6428571428571429, 'x[9] <= 0.9\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.11009933774834436, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.11672185430463576, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.12003311258278146, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.13327814569536423, 0.6904761904761905, 'x[0] <= 8.6\ngini = 0.381\nsamples = 25\nvalue = [0, 0, 5, 19, 1, 0]'),
#  Text(0.12665562913907286, 0.6428571428571429, 'x[3] <= 3.15\ngini = 0.117\nsamples = 16\nvalue = [0, 0, 0, 15, 1, 0]'),
#  Text(0.12334437086092716, 0.5952380952380952, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 15, 0, 0]'),
#  Text(0.12996688741721854, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.13990066225165562, 0.6428571428571429, 'x[10] <= 9.9\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 5, 4, 0, 0]'),
#  Text(0.13658940397350994, 0.5952380952380952, 'x[5] <= 4.0\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.13327814569536423, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.13990066225165562, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.14321192052980133, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.3236366928807947, 0.7380952380952381, 'x[0] <= 9.55\ngini = 0.525\nsamples = 261\nvalue = [0, 4, 153, 94, 10, 0]'),
#  Text(0.271445571192053, 0.6904761904761905, 'x[10] <= 9.85\ngini = 0.535\nsamples = 244\nvalue = [0, 4, 137, 94, 9, 0]'),
#  Text(0.19106995033112584, 0.6428571428571429, 'x[8] <= 3.285\ngini = 0.5\nsamples = 185\nvalue = [0, 4, 114, 64, 3, 0]'),
#  Text(0.1605960264900662, 0.5952380952380952, 'x[10] <= 9.15\ngini = 0.398\nsamples = 67\nvalue = [0, 2, 50, 14, 1, 0]'),
#  Text(0.14652317880794702, 0.5476190476190477, 'x[6] <= 30.5\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 4, 5, 0, 0]'),
#  Text(0.14321192052980133, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.1498344370860927, 0.5, 'x[1] <= 0.535\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 2, 5, 0, 0]'),
#  Text(0.14652317880794702, 0.4523809523809524, 'x[7] <= 0.997\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.14321192052980133, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1498344370860927, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.15314569536423842, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.17466887417218543, 0.5476190476190477, 'x[9] <= 1.475\ngini = 0.345\nsamples = 58\nvalue = [0, 2, 46, 9, 1, 0]'),
#  Text(0.16639072847682118, 0.5, 'x[10] <= 9.75\ngini = 0.304\nsamples = 56\nvalue = [0, 1, 46, 8, 1, 0]'),
#  Text(0.1597682119205298, 0.4523809523809524, 'x[1] <= 0.395\ngini = 0.227\nsamples = 48\nvalue = [0, 1, 42, 4, 1, 0]'),
#  Text(0.1564569536423841, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.1630794701986755, 0.40476190476190477, 'x[9] <= 0.615\ngini = 0.194\nsamples = 47\nvalue = [0, 1, 42, 4, 0, 0]'),
#  Text(0.1597682119205298, 0.35714285714285715, 'x[4] <= 0.113\ngini = 0.443\nsamples = 17\nvalue = [0, 1, 12, 4, 0, 0]'),
#  Text(0.1564569536423841, 0.30952380952380953, 'x[6] <= 93.0\ngini = 0.338\nsamples = 15\nvalue = [0, 1, 12, 2, 0, 0]'),
#  Text(0.15314569536423842, 0.2619047619047619, 'x[4] <= 0.092\ngini = 0.255\nsamples = 14\nvalue = [0, 1, 12, 1, 0, 0]'),
#  Text(0.1498344370860927, 0.21428571428571427, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.1564569536423841, 0.21428571428571427, 'x[5] <= 15.5\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 3, 1, 0, 0]'),
#  Text(0.15314569536423842, 0.16666666666666666, 'x[8] <= 3.235\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.1498344370860927, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.1564569536423841, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1597682119205298, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.1597682119205298, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1630794701986755, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.16639072847682118, 0.35714285714285715, 'gini = 0.0\nsamples = 30\nvalue = [0, 0, 30, 0, 0, 0]'),
#  Text(0.17301324503311258, 0.4523809523809524, 'x[4] <= 0.08\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 4, 4, 0, 0]'),
#  Text(0.1697019867549669, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.1763245033112583, 0.40476190476190477, 'x[1] <= 0.748\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.17301324503311258, 0.35714285714285715, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.17963576158940397, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.18294701986754966, 0.5, 'x[3] <= 2.7\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.17963576158940397, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.18625827814569537, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.22154387417218543, 0.5952380952380952, 'x[8] <= 3.325\ngini = 0.526\nsamples = 118\nvalue = [0, 2, 64, 50, 2, 0]'),
#  Text(0.20281456953642385, 0.5476190476190477, 'x[1] <= 0.61\ngini = 0.346\nsamples = 18\nvalue = [0, 0, 4, 14, 0, 0]'),
#  Text(0.19619205298013245, 0.5, 'x[2] <= 0.305\ngini = 0.142\nsamples = 13\nvalue = [0, 0, 1, 12, 0, 0]'),
#  Text(0.19288079470198677, 0.4523809523809524, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0, 0]'),
#  Text(0.19950331125827814, 0.4523809523809524, 'x[1] <= 0.495\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.19619205298013245, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.20281456953642385, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.20943708609271522, 0.5, 'x[1] <= 0.68\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.20612582781456953, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.21274834437086093, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.24027317880794702, 0.5476190476190477, 'x[0] <= 6.55\ngini = 0.51\nsamples = 100\nvalue = [0, 2, 60, 36, 2, 0]'),
#  Text(0.222682119205298, 0.5, 'x[5] <= 18.0\ngini = 0.142\nsamples = 13\nvalue = [0, 0, 12, 1, 0, 0]'),
#  Text(0.21937086092715233, 0.4523809523809524, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(0.2259933774834437, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.257864238410596, 0.5, 'x[1] <= 0.655\ngini = 0.533\nsamples = 87\nvalue = [0, 2, 48, 35, 2, 0]'),
#  Text(0.2326158940397351, 0.4523809523809524, 'x[6] <= 28.5\ngini = 0.528\nsamples = 67\nvalue = [0, 0, 33, 32, 2, 0]'),
#  Text(0.21357615894039736, 0.40476190476190477, 'x[5] <= 6.5\ngini = 0.304\nsamples = 17\nvalue = [0, 0, 2, 14, 1, 0]'),
#  Text(0.20695364238410596, 0.35714285714285715, 'x[10] <= 9.45\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.20364238410596028, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.21026490066225165, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.22019867549668873, 0.35714285714285715, 'x[9] <= 0.575\ngini = 0.133\nsamples = 14\nvalue = [0, 0, 0, 13, 1, 0]'),
#  Text(0.21688741721854304, 0.30952380952380953, 'x[2] <= 0.015\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.21357615894039736, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.22019867549668873, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.22350993377483444, 0.30952380952380953, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.25165562913907286, 0.40476190476190477, 'x[4] <= 0.079\ngini = 0.486\nsamples = 50\nvalue = [0, 0, 31, 18, 1, 0]'),
#  Text(0.2367549668874172, 0.35714285714285715, 'x[5] <= 26.5\ngini = 0.287\nsamples = 23\nvalue = [0, 0, 19, 4, 0, 0]'),
#  Text(0.23013245033112584, 0.30952380952380953, 'x[6] <= 35.5\ngini = 0.18\nsamples = 20\nvalue = [0, 0, 18, 2, 0, 0]'),
#  Text(0.22682119205298013, 0.2619047619047619, 'x[3] <= 2.0\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(0.22350993377483444, 0.21428571428571427, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.23013245033112584, 0.21428571428571427, 'x[7] <= 0.996\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.22682119205298013, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.23344370860927152, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.23344370860927152, 0.2619047619047619, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(0.2433774834437086, 0.30952380952380953, 'x[5] <= 30.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.24006622516556292, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.24668874172185432, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.26655629139072845, 0.35714285714285715, 'x[3] <= 2.55\ngini = 0.532\nsamples = 27\nvalue = [0, 0, 12, 14, 1, 0]'),
#  Text(0.2632450331125828, 0.30952380952380953, 'x[0] <= 7.45\ngini = 0.507\nsamples = 23\nvalue = [0, 0, 8, 14, 1, 0]'),
#  Text(0.2533112582781457, 0.2619047619047619, 'x[9] <= 0.69\ngini = 0.298\nsamples = 11\nvalue = [0, 0, 2, 9, 0, 0]'),
#  Text(0.25, 0.21428571428571427, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.25662251655629137, 0.21428571428571427, 'x[10] <= 9.65\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.2533112582781457, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2599337748344371, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2731788079470199, 0.2619047619047619, 'x[7] <= 0.998\ngini = 0.569\nsamples = 12\nvalue = [0, 0, 6, 5, 1, 0]'),
#  Text(0.26986754966887416, 0.21428571428571427, 'x[6] <= 43.5\ngini = 0.406\nsamples = 8\nvalue = [0, 0, 6, 1, 1, 0]'),
#  Text(0.26655629139072845, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2731788079470199, 0.16666666666666666, 'x[6] <= 53.5\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.26986754966887416, 0.11904761904761904, 'x[9] <= 0.69\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.26655629139072845, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2731788079470199, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2764900662251656, 0.11904761904761904, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.2764900662251656, 0.21428571428571427, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.26986754966887416, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.28311258278145696, 0.4523809523809524, 'x[9] <= 0.695\ngini = 0.405\nsamples = 20\nvalue = [0, 2, 15, 3, 0, 0]'),
#  Text(0.2764900662251656, 0.40476190476190477, 'x[7] <= 0.996\ngini = 0.124\nsamples = 15\nvalue = [0, 1, 14, 0, 0, 0]'),
#  Text(0.2731788079470199, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.27980132450331124, 0.35714285714285715, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0, 0, 0]'),
#  Text(0.2897350993377483, 0.40476190476190477, 'x[5] <= 19.0\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 1, 3, 0, 0]'),
#  Text(0.28642384105960267, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.29304635761589404, 0.35714285714285715, 'x[7] <= 0.999\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.2897350993377483, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.29635761589403975, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3518211920529801, 0.6428571428571429, 'x[1] <= 0.75\ngini = 0.579\nsamples = 59\nvalue = [0, 0, 23, 30, 6, 0]'),
#  Text(0.34105960264900664, 0.5952380952380952, 'x[4] <= 0.103\ngini = 0.555\nsamples = 53\nvalue = [0, 0, 18, 30, 5, 0]'),
#  Text(0.3294701986754967, 0.5476190476190477, 'x[5] <= 28.0\ngini = 0.525\nsamples = 49\nvalue = [0.0, 0.0, 15.0, 30.0, 4.0, 0.0]'),
#  Text(0.3162251655629139, 0.5, 'x[9] <= 0.615\ngini = 0.445\nsamples = 40\nvalue = [0, 0, 10, 28, 2, 0]'),
#  Text(0.30629139072847683, 0.4523809523809524, 'x[9] <= 0.585\ngini = 0.494\nsamples = 18\nvalue = [0, 0, 8, 10, 0, 0]'),
#  Text(0.3029801324503311, 0.40476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.30960264900662254, 0.40476190476190477, 'x[7] <= 0.998\ngini = 0.444\nsamples = 12\nvalue = [0, 0, 8, 4, 0, 0]'),
#  Text(0.30629139072847683, 0.35714285714285715, 'x[1] <= 0.6\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 8, 2, 0, 0]'),
#  Text(0.3029801324503311, 0.30952380952380953, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.30960264900662254, 0.30952380952380953, 'x[6] <= 24.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.30629139072847683, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3129139072847682, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3129139072847682, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.326158940397351, 0.4523809523809524, 'x[1] <= 0.695\ngini = 0.314\nsamples = 22\nvalue = [0, 0, 2, 18, 2, 0]'),
#  Text(0.3228476821192053, 0.40476190476190477, 'x[0] <= 7.05\ngini = 0.18\nsamples = 20\nvalue = [0, 0, 0, 18, 2, 0]'),
#  Text(0.3195364238410596, 0.35714285714285715, 'x[5] <= 14.5\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 5, 2, 0]'),
#  Text(0.3162251655629139, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.3228476821192053, 0.30952380952380953, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.326158940397351, 0.35714285714285715, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0, 0]'),
#  Text(0.3294701986754967, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.34271523178807944, 0.5, 'x[4] <= 0.064\ngini = 0.593\nsamples = 9\nvalue = [0, 0, 5, 2, 2, 0]'),
#  Text(0.3394039735099338, 0.4523809523809524, 'x[2] <= 0.31\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 0, 2, 2, 0]'),
#  Text(0.3360927152317881, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.34271523178807944, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.34602649006622516, 0.4523809523809524, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.3526490066225166, 0.5476190476190477, 'x[2] <= 0.09\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 0, 1, 0]'),
#  Text(0.34933774834437087, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.35596026490066224, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.36258278145695366, 0.5952380952380952, 'x[5] <= 8.5\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 0, 1, 0]'),
#  Text(0.35927152317880795, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3658940397350993, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.3758278145695364, 0.6904761904761905, 'x[1] <= 0.52\ngini = 0.111\nsamples = 17\nvalue = [0, 0, 16, 0, 1, 0]'),
#  Text(0.37251655629139074, 0.6428571428571429, 'x[3] <= 2.4\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 0, 1, 0]'),
#  Text(0.36920529801324503, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3758278145695364, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.3791390728476821, 0.6428571428571429, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(0.4457781456953642, 0.7857142857142857, 'x[4] <= 0.12\ngini = 0.556\nsamples = 74\nvalue = [3, 2, 16, 46, 7, 0]'),
#  Text(0.4197019867549669, 0.7380952380952381, 'x[0] <= 11.55\ngini = 0.495\nsamples = 63\nvalue = [1, 2, 10, 43, 7, 0]'),
#  Text(0.3973509933774834, 0.6904761904761905, 'x[3] <= 2.25\ngini = 0.352\nsamples = 41\nvalue = [0, 1, 8, 32, 0, 0]'),
#  Text(0.38576158940397354, 0.6428571428571429, 'x[1] <= 0.575\ngini = 0.105\nsamples = 18\nvalue = [0, 1, 0, 17, 0, 0]'),
#  Text(0.3824503311258278, 0.5952380952380952, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 0, 16, 0, 0]'),
#  Text(0.3890728476821192, 0.5952380952380952, 'x[3] <= 2.15\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.38576158940397354, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3923841059602649, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.40894039735099336, 0.6428571428571429, 'x[2] <= 0.56\ngini = 0.454\nsamples = 23\nvalue = [0, 0, 8, 15, 0, 0]'),
#  Text(0.4056291390728477, 0.5952380952380952, 'x[9] <= 0.68\ngini = 0.375\nsamples = 20\nvalue = [0, 0, 5, 15, 0, 0]'),
#  Text(0.3990066225165563, 0.5476190476190477, 'x[0] <= 10.35\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 4, 4, 0, 0]'),
#  Text(0.3956953642384106, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.402317880794702, 0.5, 'x[6] <= 86.0\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.3990066225165563, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.4056291390728477, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.41225165562913907, 0.5476190476190477, 'x[6] <= 17.5\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 1, 11, 0, 0]'),
#  Text(0.40894039735099336, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4155629139072848, 0.5, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0, 0]'),
#  Text(0.41225165562913907, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.4420529801324503, 0.6904761904761905, 'x[9] <= 0.715\ngini = 0.636\nsamples = 22\nvalue = [1, 1, 2, 11, 7, 0]'),
#  Text(0.4288079470198676, 0.6428571428571429, 'x[6] <= 44.0\ngini = 0.497\nsamples = 13\nvalue = [1, 1, 1, 9, 1, 0]'),
#  Text(0.42218543046357615, 0.5952380952380952, 'x[8] <= 2.99\ngini = 0.314\nsamples = 11\nvalue = [0, 0, 1, 9, 1, 0]'),
#  Text(0.41887417218543044, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.42549668874172186, 0.5476190476190477, 'x[1] <= 0.595\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 1, 9, 0, 0]'),
#  Text(0.42218543046357615, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.4288079470198676, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.43543046357615894, 0.5952380952380952, 'x[8] <= 3.15\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0, 0]'),
#  Text(0.43211920529801323, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.43874172185430466, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.4552980132450331, 0.6428571428571429, 'x[6] <= 22.5\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 1, 2, 6, 0]'),
#  Text(0.44867549668874174, 0.5952380952380952, 'x[4] <= 0.069\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.445364238410596, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4519867549668874, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.46192052980132453, 0.5952380952380952, 'x[2] <= 0.67\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 1, 6, 0]'),
#  Text(0.4586092715231788, 0.5476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.4652317880794702, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4718543046357616, 0.7380952380952381, 'x[4] <= 0.207\ngini = 0.595\nsamples = 11\nvalue = [2, 0, 6, 3, 0, 0]'),
#  Text(0.4685430463576159, 0.6904761904761905, 'x[8] <= 3.155\ngini = 0.375\nsamples = 8\nvalue = [2, 0, 6, 0, 0, 0]'),
#  Text(0.4652317880794702, 0.6428571428571429, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.4718543046357616, 0.6428571428571429, 'x[7] <= 1.0\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1, 0, 0, 0]'),
#  Text(0.4685430463576159, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]'),
#  Text(0.47516556291390727, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.47516556291390727, 0.6904761904761905, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.478476821192053, 0.8809523809523809, 'x[8] <= 3.085\ngini = 0.089\nsamples = 87\nvalue = [0, 1, 83, 3, 0, 0]'),
#  Text(0.4718543046357616, 0.8333333333333334, 'x[2] <= 0.285\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(0.4685430463576159, 0.7857142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.47516556291390727, 0.7857142857142857, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.48509933774834435, 0.8333333333333334, 'x[10] <= 9.15\ngini = 0.049\nsamples = 80\nvalue = [0, 1, 78, 1, 0, 0]'),
#  Text(0.4817880794701987, 0.7857142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.48841059602649006, 0.7857142857142857, 'x[6] <= 98.5\ngini = 0.025\nsamples = 79\nvalue = [0, 0, 78, 1, 0, 0]'),
#  Text(0.48509933774834435, 0.7380952380952381, 'x[0] <= 8.4\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.4817880794701987, 0.6904761904761905, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.48841059602649006, 0.6904761904761905, 'x[4] <= 0.099\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.48509933774834435, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4917218543046358, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4917218543046358, 0.7380952380952381, 'gini = 0.0\nsamples = 72\nvalue = [0, 0, 72, 0, 0, 0]'),
#  Text(0.7079366721854304, 0.9285714285714286, 'x[1] <= 0.385\ngini = 0.66\nsamples = 568\nvalue = [2, 19, 126, 275, 133, 13]'),
#  Text(0.6155086289967922, 0.9523809523809523, '  False'),
#  Text(0.5635347682119205, 0.8809523809523809, 'x[7] <= 0.995\ngini = 0.64\nsamples = 186\nvalue = [0.0, 1.0, 26.0, 73.0, 80.0, 6.0]'),
#  Text(0.5260761589403974, 0.8333333333333334, 'x[1] <= 0.275\ngini = 0.538\nsamples = 78\nvalue = [0, 0, 4, 26, 46, 2]'),
#  Text(0.5066225165562914, 0.7857142857142857, 'x[9] <= 0.615\ngini = 0.562\nsamples = 18\nvalue = [0, 0, 2, 11, 4, 1]'),
#  Text(0.49834437086092714, 0.7380952380952381, 'x[3] <= 3.75\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 0, 9, 1, 0]'),
#  Text(0.49503311258278143, 0.6904761904761905, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.5016556291390728, 0.6904761904761905, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5149006622516556, 0.7380952380952381, 'x[2] <= 0.385\ngini = 0.719\nsamples = 8\nvalue = [0, 0, 2, 2, 3, 1]'),
#  Text(0.5082781456953642, 0.6904761904761905, 'x[4] <= 0.065\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]'),
#  Text(0.5049668874172185, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.5115894039735099, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5215231788079471, 0.6904761904761905, 'x[10] <= 11.15\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 0, 1]'),
#  Text(0.5182119205298014, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.5248344370860927, 0.6428571428571429, 'x[2] <= 0.59\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.5215231788079471, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.5281456953642384, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5455298013245033, 0.7857142857142857, 'x[2] <= 0.27\ngini = 0.446\nsamples = 60\nvalue = [0, 0, 2, 15, 42, 1]'),
#  Text(0.5422185430463576, 0.7380952380952381, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.5488410596026491, 0.7380952380952381, 'x[3] <= 1.3\ngini = 0.397\nsamples = 56\nvalue = [0, 0, 2, 11, 42, 1]'),
#  Text(0.5455298013245033, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5521523178807947, 0.6904761904761905, 'x[4] <= 0.095\ngini = 0.366\nsamples = 54\nvalue = [0, 0, 2, 9, 42, 1]'),
#  Text(0.543046357615894, 0.6428571428571429, 'x[3] <= 2.025\ngini = 0.333\nsamples = 51\nvalue = [0.0, 0.0, 2.0, 7.0, 41.0, 1.0]'),
#  Text(0.5347682119205298, 0.5952380952380952, 'x[5] <= 23.5\ngini = 0.549\nsamples = 21\nvalue = [0, 0, 2, 5, 13, 1]'),
#  Text(0.5281456953642384, 0.5476190476190477, 'x[8] <= 3.395\ngini = 0.444\nsamples = 18\nvalue = [0, 0, 1, 3, 13, 1]'),
#  Text(0.5248344370860927, 0.5, 'x[0] <= 9.85\ngini = 0.394\nsamples = 17\nvalue = [0, 0, 1, 2, 13, 1]'),
#  Text(0.5215231788079471, 0.4523809523809524, 'x[7] <= 0.994\ngini = 0.328\nsamples = 16\nvalue = [0, 0, 1, 1, 13, 1]'),
#  Text(0.5182119205298014, 0.40476190476190477, 'x[4] <= 0.061\ngini = 0.612\nsamples = 7\nvalue = [0, 0, 1, 1, 4, 1]'),
#  Text(0.5115894039735099, 0.35714285714285715, 'x[9] <= 0.63\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.5082781456953642, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5149006622516556, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5248344370860927, 0.35714285714285715, 'x[8] <= 3.245\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 0, 4, 1]'),
#  Text(0.5215231788079471, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.5281456953642384, 0.30952380952380953, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.5248344370860927, 0.40476190476190477, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 0, 9, 0]'),
#  Text(0.5281456953642384, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5314569536423841, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5413907284768212, 0.5476190476190477, 'x[9] <= 0.69\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.5380794701986755, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5447019867549668, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5513245033112583, 0.5952380952380952, 'x[1] <= 0.335\ngini = 0.124\nsamples = 30\nvalue = [0, 0, 0, 2, 28, 0]'),
#  Text(0.5480132450331126, 0.5476190476190477, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 0, 0, 20, 0]'),
#  Text(0.554635761589404, 0.5476190476190477, 'x[9] <= 0.645\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 0, 2, 8, 0]'),
#  Text(0.5513245033112583, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5579470198675497, 0.5, 'x[8] <= 3.155\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 1, 8, 0]'),
#  Text(0.554635761589404, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5612582781456954, 0.4523809523809524, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 8, 0]'),
#  Text(0.5612582781456954, 0.6428571428571429, 'x[4] <= 0.205\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.5579470198675497, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5645695364238411, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.6009933774834437, 0.8333333333333334, 'x[9] <= 0.575\ngini = 0.669\nsamples = 108\nvalue = [0, 1, 22, 47, 34, 4]'),
#  Text(0.5831953642384106, 0.7857142857142857, 'x[4] <= 0.061\ngini = 0.165\nsamples = 11\nvalue = [0, 1, 0, 10, 0, 0]'),
#  Text(0.5798841059602649, 0.7380952380952381, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5865066225165563, 0.7380952380952381, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.6187913907284768, 0.7857142857142857, 'x[0] <= 9.35\ngini = 0.678\nsamples = 97\nvalue = [0, 0, 22, 37, 34, 4]'),
#  Text(0.5931291390728477, 0.7380952380952381, 'x[2] <= 0.485\ngini = 0.629\nsamples = 48\nvalue = [0, 0, 14, 24, 9, 1]'),
#  Text(0.5836092715231788, 0.6904761904761905, 'x[10] <= 11.85\ngini = 0.598\nsamples = 41\nvalue = [0.0, 0.0, 8.0, 23.0, 9.0, 1.0]'),
#  Text(0.5745033112582781, 0.6428571428571429, 'x[4] <= 0.058\ngini = 0.532\nsamples = 35\nvalue = [0, 0, 8, 22, 5, 0]'),
#  Text(0.5711920529801324, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.5778145695364238, 0.5952380952380952, 'x[0] <= 7.6\ngini = 0.479\nsamples = 32\nvalue = [0, 0, 5, 22, 5, 0]'),
#  Text(0.5695364238410596, 0.5476190476190477, 'x[7] <= 0.996\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.5662251655629139, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5728476821192053, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.5860927152317881, 0.5476190476190477, 'x[6] <= 21.0\ngini = 0.412\nsamples = 27\nvalue = [0, 0, 2, 20, 5, 0]'),
#  Text(0.5794701986754967, 0.5, 'x[8] <= 3.37\ngini = 0.62\nsamples = 10\nvalue = [0, 0, 2, 5, 3, 0]'),
#  Text(0.5761589403973509, 0.4523809523809524, 'x[5] <= 5.5\ngini = 0.469\nsamples = 8\nvalue = [0, 0, 0, 5, 3, 0]'),
#  Text(0.5728476821192053, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.5794701986754967, 0.40476190476190477, 'x[10] <= 11.3\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 2, 3, 0]'),
#  Text(0.5761589403973509, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.5827814569536424, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5827814569536424, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.5927152317880795, 0.5, 'x[5] <= 47.0\ngini = 0.208\nsamples = 17\nvalue = [0, 0, 0, 15, 2, 0]'),
#  Text(0.5894039735099338, 0.4523809523809524, 'x[10] <= 11.25\ngini = 0.117\nsamples = 16\nvalue = [0, 0, 0, 15, 1, 0]'),
#  Text(0.5860927152317881, 0.40476190476190477, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0, 0]'),
#  Text(0.5927152317880795, 0.40476190476190477, 'x[9] <= 0.75\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.5894039735099338, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5960264900662252, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5960264900662252, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5927152317880795, 0.6428571428571429, 'x[7] <= 0.996\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 0, 1, 4, 1]'),
#  Text(0.5894039735099338, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.5960264900662252, 0.5952380952380952, 'x[3] <= 2.8\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.5927152317880795, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5993377483443708, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.6026490066225165, 0.6904761904761905, 'x[0] <= 7.2\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.5993377483443708, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6059602649006622, 0.6428571428571429, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.644453642384106, 0.7380952380952381, 'x[5] <= 9.5\ngini = 0.639\nsamples = 49\nvalue = [0.0, 0.0, 8.0, 13.0, 25.0, 3.0]'),
#  Text(0.6299668874172185, 0.6904761904761905, 'x[6] <= 18.5\ngini = 0.475\nsamples = 27\nvalue = [0, 0, 2, 3, 19, 3]'),
#  Text(0.6208609271523179, 0.6428571428571429, 'x[8] <= 3.24\ngini = 0.663\nsamples = 14\nvalue = [0, 0, 2, 2, 7, 3]'),
#  Text(0.6125827814569537, 0.5952380952380952, 'x[3] <= 2.5\ngini = 0.512\nsamples = 11\nvalue = [0, 0, 0, 1, 7, 3]'),
#  Text(0.6059602649006622, 0.5476190476190477, 'x[7] <= 0.996\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 1, 6, 0]'),
#  Text(0.6026490066225165, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.609271523178808, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.6192052980132451, 0.5476190476190477, 'x[7] <= 0.997\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 0, 1, 3]'),
#  Text(0.6158940397350994, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3]'),
#  Text(0.6225165562913907, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.6291390728476821, 0.5952380952380952, 'x[3] <= 1.95\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.6258278145695364, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6324503311258278, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.6390728476821192, 0.6428571428571429, 'x[1] <= 0.375\ngini = 0.142\nsamples = 13\nvalue = [0, 0, 0, 1, 12, 0]'),
#  Text(0.6357615894039735, 0.5952380952380952, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 0, 12, 0]'),
#  Text(0.6423841059602649, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6589403973509934, 0.6904761904761905, 'x[10] <= 10.9\ngini = 0.645\nsamples = 22\nvalue = [0, 0, 6, 10, 6, 0]'),
#  Text(0.652317880794702, 0.6428571428571429, 'x[9] <= 0.64\ngini = 0.58\nsamples = 10\nvalue = [0, 0, 4, 1, 5, 0]'),
#  Text(0.6490066225165563, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.6556291390728477, 0.5952380952380952, 'x[1] <= 0.35\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 1, 1, 5, 0]'),
#  Text(0.652317880794702, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.6589403973509934, 0.5476190476190477, 'x[5] <= 28.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.6556291390728477, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6622516556291391, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6655629139072847, 0.6428571428571429, 'x[2] <= 0.645\ngini = 0.403\nsamples = 12\nvalue = [0, 0, 2, 9, 1, 0]'),
#  Text(0.6622516556291391, 0.5952380952380952, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.6688741721854304, 0.5952380952380952, 'x[2] <= 0.685\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 1, 0]'),
#  Text(0.6655629139072847, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.6721854304635762, 0.5476190476190477, 'x[9] <= 0.665\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.6688741721854304, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6754966887417219, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8523385761589404, 0.8809523809523809, 'x[10] <= 11.45\ngini = 0.63\nsamples = 382\nvalue = [2.0, 18.0, 100.0, 202.0, 53.0, 7.0]'),
#  Text(0.7717301324503312, 0.8333333333333334, 'x[9] <= 0.575\ngini = 0.601\nsamples = 257\nvalue = [2, 15, 87, 135, 18, 0]'),
#  Text(0.7264072847682119, 0.7857142857142857, 'x[10] <= 10.85\ngini = 0.631\nsamples = 74\nvalue = [2, 8, 37, 24, 3, 0]'),
#  Text(0.7044701986754967, 0.7380952380952381, 'x[7] <= 0.994\ngini = 0.602\nsamples = 41\nvalue = [0, 3, 16, 20, 2, 0]'),
#  Text(0.7011589403973509, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.7077814569536424, 0.6904761904761905, 'x[3] <= 3.15\ngini = 0.565\nsamples = 39\nvalue = [0, 1, 16, 20, 2, 0]'),
#  Text(0.7044701986754967, 0.6428571428571429, 'x[3] <= 2.55\ngini = 0.58\nsamples = 34\nvalue = [0, 1, 16, 15, 2, 0]'),
#  Text(0.6937086092715232, 0.5952380952380952, 'x[2] <= 0.025\ngini = 0.578\nsamples = 23\nvalue = [0.0, 1.0, 7.0, 13.0, 2.0, 0.0]'),
#  Text(0.6854304635761589, 0.5476190476190477, 'x[0] <= 7.65\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 0, 8, 2, 0]'),
#  Text(0.6821192052980133, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.6887417218543046, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.7019867549668874, 0.5476190476190477, 'x[4] <= 0.079\ngini = 0.556\nsamples = 13\nvalue = [0, 1, 7, 5, 0, 0]'),
#  Text(0.695364238410596, 0.5, 'x[0] <= 7.4\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.6920529801324503, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6986754966887417, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.7086092715231788, 0.5, 'x[4] <= 0.102\ngini = 0.406\nsamples = 8\nvalue = [0, 1, 6, 1, 0, 0]'),
#  Text(0.7052980132450332, 0.4523809523809524, 'x[0] <= 6.85\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.7019867549668874, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7086092715231788, 0.40476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.7119205298013245, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.7152317880794702, 0.5952380952380952, 'x[8] <= 3.23\ngini = 0.298\nsamples = 11\nvalue = [0, 0, 9, 2, 0, 0]'),
#  Text(0.7119205298013245, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7185430463576159, 0.5476190476190477, 'x[1] <= 0.435\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 9, 1, 0, 0]'),
#  Text(0.7152317880794702, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7218543046357616, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.7110927152317881, 0.6428571428571429, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
# ...
#  Text(0.7326158940397351, 0.16666666666666666, 'x[9] <= 0.585\ngini = 0.304\nsamples = 17\nvalue = [0, 1, 2, 14, 0, 0]'),
#  Text(0.7293046357615894, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.7359271523178808, 0.11904761904761904, 'x[7] <= 0.995\ngini = 0.219\nsamples = 16\nvalue = [0, 0, 2, 14, 0, 0]'),
#  Text(0.7326158940397351, 0.07142857142857142, 'x[0] <= 8.55\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 1, 14, 0, 0]'),
#  Text(0.7293046357615894, 0.023809523809523808, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.7359271523178808, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7392384105960265, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7392384105960265, 0.16666666666666666, 'gini = 0.0\nsamples = 40\nvalue = [0, 0, 0, 40, 0, 0]'),
#  Text(0.7491721854304636, 0.21428571428571427, 'x[3] <= 2.45\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.7458609271523179, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7524834437086093, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7690397350993378, 0.2619047619047619, 'x[3] <= 1.95\ngini = 0.406\nsamples = 24\nvalue = [0, 1, 4, 18, 1, 0]'),
#  Text(0.7624172185430463, 0.21428571428571427, 'x[9] <= 0.8\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.7591059602649006, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.765728476821192, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7756622516556292, 0.21428571428571427, 'x[7] <= 0.997\ngini = 0.283\nsamples = 19\nvalue = [0, 1, 1, 16, 1, 0]'),
#  Text(0.7723509933774835, 0.16666666666666666, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.7789735099337748, 0.16666666666666666, 'x[10] <= 10.45\ngini = 0.72\nsamples = 5\nvalue = [0, 1, 1, 2, 1, 0]'),
#  Text(0.7756622516556292, 0.11904761904761904, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7822847682119205, 0.11904761904761904, 'x[4] <= 0.075\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 0, 1, 0]'),
#  Text(0.7789735099337748, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.7855960264900662, 0.07142857142857142, 'x[4] <= 0.083\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.7822847682119205, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7889072847682119, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7789735099337748, 0.30952380952380953, 'x[9] <= 0.75\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 3, 2, 0]'),
#  Text(0.7756622516556292, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.7822847682119205, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.7889072847682119, 0.35714285714285715, 'x[2] <= 0.245\ngini = 0.444\nsamples = 12\nvalue = [0, 0, 4, 8, 0, 0]'),
#  Text(0.7855960264900662, 0.30952380952380953, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.7922185430463576, 0.30952380952380953, 'x[5] <= 23.5\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(0.7889072847682119, 0.2619047619047619, 'x[6] <= 38.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.7855960264900662, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7922185430463576, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7955298013245033, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.7847682119205298, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7880794701986755, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7913907284768212, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7831125827814569, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.8129139072847682, 0.6904761904761905, 'x[3] <= 2.55\ngini = 0.65\nsamples = 32\nvalue = [0, 3, 14, 12, 3, 0]'),
#  Text(0.804635761589404, 0.6428571428571429, 'x[4] <= 0.117\ngini = 0.51\nsamples = 20\nvalue = [0, 1, 13, 5, 1, 0]'),
#  Text(0.7980132450331126, 0.5952380952380952, 'x[1] <= 0.395\ngini = 0.153\nsamples = 12\nvalue = [0, 1, 11, 0, 0, 0]'),
#  Text(0.7947019867549668, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8013245033112583, 0.5476190476190477, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.8112582781456954, 0.5952380952380952, 'x[10] <= 10.95\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 2, 5, 1, 0]'),
#  Text(0.8079470198675497, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.8145695364238411, 0.5476190476190477, 'x[2] <= 0.175\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 1, 0]'),
#  Text(0.8112582781456954, 0.5, 'x[2] <= 0.14\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.8079470198675497, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8145695364238411, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8178807947019867, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8211920529801324, 0.6428571428571429, 'x[3] <= 2.9\ngini = 0.597\nsamples = 12\nvalue = [0, 2, 1, 7, 2, 0]'),
#  Text(0.8178807947019867, 0.5952380952380952, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.8245033112582781, 0.5952380952380952, 'x[8] <= 3.29\ngini = 0.722\nsamples = 6\nvalue = [0, 2, 1, 1, 2, 0]'),
#  Text(0.8211920529801324, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8278145695364238, 0.5476190476190477, 'x[5] <= 17.5\ngini = 0.625\nsamples = 4\nvalue = [0, 2, 1, 1, 0, 0]'),
#  Text(0.8245033112582781, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.8311258278145696, 0.5, 'x[6] <= 42.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.8278145695364238, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8344370860927153, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8377483443708609, 0.7380952380952381, 'x[2] <= 0.34\ngini = 0.526\nsamples = 21\nvalue = [0, 0, 13, 2, 6, 0]'),
#  Text(0.8311258278145696, 0.6904761904761905, 'x[6] <= 48.0\ngini = 0.449\nsamples = 7\nvalue = [0, 0, 1, 1, 5, 0]'),
#  Text(0.8278145695364238, 0.6428571428571429, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.8344370860927153, 0.6428571428571429, 'x[0] <= 6.8\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.8311258278145696, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8377483443708609, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8443708609271523, 0.6904761904761905, 'x[3] <= 6.2\ngini = 0.255\nsamples = 14\nvalue = [0, 0, 12, 1, 1, 0]'),
#  Text(0.8410596026490066, 0.6428571428571429, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(0.847682119205298, 0.6428571428571429, 'x[2] <= 0.45\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.8443708609271523, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8509933774834437, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9329470198675497, 0.8333333333333334, 'x[9] <= 0.705\ngini = 0.62\nsamples = 125\nvalue = [0, 3, 13, 67, 35, 7]'),
#  Text(0.8956953642384106, 0.7857142857142857, 'x[6] <= 15.5\ngini = 0.532\nsamples = 81\nvalue = [0, 3, 12, 53, 10, 3]'),
#  Text(0.8692052980132451, 0.7380952380952381, 'x[4] <= 0.084\ngini = 0.727\nsamples = 17\nvalue = [0, 2, 3, 4, 7, 1]'),
#  Text(0.8609271523178808, 0.6904761904761905, 'x[7] <= 0.993\ngini = 0.744\nsamples = 11\nvalue = [0, 1, 3, 4, 2, 1]'),
#  Text(0.8576158940397351, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8642384105960265, 0.6428571428571429, 'x[3] <= 4.55\ngini = 0.716\nsamples = 9\nvalue = [0, 1, 1, 4, 2, 1]'),
#  Text(0.8576158940397351, 0.5952380952380952, 'x[9] <= 0.64\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 0, 4, 1, 1]'),
#  Text(0.8543046357615894, 0.5476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.8609271523178808, 0.5476190476190477, 'x[7] <= 0.994\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.8576158940397351, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8642384105960265, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.8708609271523179, 0.5952380952380952, 'x[9] <= 0.495\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 0, 1, 0]'),
#  Text(0.8675496688741722, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8741721854304636, 0.5476190476190477, 'x[5] <= 4.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.8708609271523179, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8774834437086093, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8774834437086093, 0.6904761904761905, 'x[6] <= 12.0\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 0, 0, 5, 0]'),
#  Text(0.8741721854304636, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.8807947019867549, 0.6428571428571429, 'x[5] <= 6.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]'),
#  Text(0.8774834437086093, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8841059602649006, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9221854304635762, 0.7380952380952381, 'x[6] <= 93.5\ngini = 0.391\nsamples = 64\nvalue = [0, 1, 9, 49, 3, 2]'),
#  Text(0.9072847682119205, 0.6904761904761905, 'x[1] <= 0.555\ngini = 0.33\nsamples = 58\nvalue = [0, 1, 6, 47, 2, 2]'),
#  Text(0.8940397350993378, 0.6428571428571429, 'x[6] <= 19.5\ngini = 0.127\nsamples = 30\nvalue = [0, 0, 0, 28, 1, 1]'),
#  Text(0.890728476821192, 0.5952380952380952, 'x[8] <= 3.29\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 0, 2, 1, 1]'),
#  Text(0.8874172185430463, 0.5476190476190477, 'x[5] <= 9.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.8841059602649006, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.890728476821192, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8940397350993378, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8973509933774835, 0.5952380952380952, 'gini = 0.0\nsamples = 26\nvalue = [0, 0, 0, 26, 0, 0]'),
#  Text(0.9205298013245033, 0.6428571428571429, 'x[3] <= 3.475\ngini = 0.49\nsamples = 28\nvalue = [0, 1, 6, 19, 1, 1]'),
#  Text(0.9105960264900662, 0.5952380952380952, 'x[2] <= 0.04\ngini = 0.381\nsamples = 25\nvalue = [0, 0, 5, 19, 1, 0]'),
#  Text(0.9006622516556292, 0.5476190476190477, 'x[1] <= 0.778\ngini = 0.227\nsamples = 16\nvalue = [0, 0, 1, 14, 1, 0]'),
#  Text(0.8973509933774835, 0.5, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.9039735099337748, 0.5, 'x[5] <= 27.5\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 2, 1, 0]'),
#  Text(0.9006622516556292, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9072847682119205, 0.4523809523809524, 'x[10] <= 11.95\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.9039735099337748, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9105960264900662, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9205298013245033, 0.5476190476190477, 'x[6] <= 49.5\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 4, 5, 0, 0]'),
#  Text(0.9172185430463576, 0.5, 'x[10] <= 11.65\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(0.9139072847682119, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9205298013245033, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.9238410596026491, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9304635761589404, 0.5952380952380952, 'x[5] <= 7.0\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 0, 0, 1]'),
#  Text(0.9271523178807947, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9337748344370861, 0.5476190476190477, 'x[5] <= 9.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.9304635761589404, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9370860927152318, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9370860927152318, 0.6904761904761905, 'x[6] <= 102.5\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 3, 2, 1, 0]'),
#  Text(0.9337748344370861, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.9403973509933775, 0.6428571428571429, 'x[3] <= 1.65\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.9370860927152318, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9437086092715232, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9701986754966887, 0.7857142857142857, 'x[5] <= 5.5\ngini = 0.567\nsamples = 44\nvalue = [0.0, 0.0, 1.0, 14.0, 25.0, 4.0]'),
#  Text(0.9668874172185431, 0.7380952380952381, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.9735099337748344, 0.7380952380952381, 'x[5] <= 18.5\ngini = 0.536\nsamples = 40\nvalue = [0, 0, 1, 10, 25, 4]'),
#  Text(0.9602649006622517, 0.6904761904761905, 'x[7] <= 0.998\ngini = 0.299\nsamples = 23\nvalue = [0, 0, 0, 3, 19, 1]'),
#  Text(0.9536423841059603, 0.6428571428571429, 'x[9] <= 0.725\ngini = 0.105\nsamples = 18\nvalue = [0, 0, 0, 0, 17, 1]'),
#  Text(0.9503311258278145, 0.5952380952380952, 'x[0] <= 7.75\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 2, 1]'),
#  Text(0.9470198675496688, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9536423841059603, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.956953642384106, 0.5952380952380952, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 0, 15, 0]'),
#  Text(0.9668874172185431, 0.6428571428571429, 'x[9] <= 0.885\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 3, 2, 0]'),
#  Text(0.9635761589403974, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9701986754966887, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9867549668874173, 0.6904761904761905, 'x[10] <= 12.65\ngini = 0.671\nsamples = 17\nvalue = [0, 0, 1, 7, 6, 3]'),
#  Text(0.9801324503311258, 0.6428571428571429, 'x[8] <= 3.375\ngini = 0.497\nsamples = 13\nvalue = [0, 0, 0, 7, 6, 0]'),
#  Text(0.9768211920529801, 0.5952380952380952, 'x[6] <= 52.0\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 0, 2, 6, 0]'),
#  Text(0.9735099337748344, 0.5476190476190477, 'x[4] <= 0.078\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.9701986754966887, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9768211920529801, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9801324503311258, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.9834437086092715, 0.5952380952380952, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.9933774834437086, 0.6428571428571429, 'x[4] <= 0.092\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 0, 0, 3]'),
#  Text(0.9900662251655629, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3]'),
#  Text(0.9966887417218543, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]')]

# %% [markdown]
# # Evaluation Matrix

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.16      0.25      0.19        12
#            5       0.68      0.64      0.66       169
#            6       0.62      0.59      0.60       167
#            7       0.45      0.54      0.50        46
#            8       0.00      0.00      0.00         4
#
#     accuracy                           0.59       400
#    macro avg       0.32      0.34      0.33       400
# weighted avg       0.60      0.59      0.59       400

# %% [markdown]
# # Feature importance

# %%
from sklearn.datasets import make_classification
# Generate a random n_class classification problem
X, Y = make_classification(n_samples = 10, n_classes = 2, n_features = 2, n_informative = 2, n_redundant = 0, random_state = 0)
clf = DecisionTreeClassifier()
clf.fit(X,Y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clf)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 0.914\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.625, 0.5, '  False')]

# %%
clf.feature_importances_
# Out:
# array([1., 0.])
